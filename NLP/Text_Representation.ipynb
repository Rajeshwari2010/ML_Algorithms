# %% [markdown]
# One HOT Encoder

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Sample data
df = pd.DataFrame({
    'Color': ['Red', 'Blue', 'Green', 'Red', 'Blue']
})

encoder = OneHotEncoder(sparse_output=False)

encoded = encoder.fit_transform(df[['Color']])

print(encoded)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]

# %%
from sklearn.feature_extraction.text import CountVectorizer

corpus = [
    "I love Python",
    "Python is easy",
    "I love NLP"
]

cv = CountVectorizer()

X = cv.fit_transform(corpus)

print(cv.get_feature_names_out())
print(cv.vocabulary)
print(X.toarray())
# Out:
# ['easy' 'is' 'love' 'nlp' 'python']
# None
# [[0 0 1 0 1]
#  [1 1 0 0 1]
#  [0 0 1 1 0]]

# %%
cv.transform(["I love programming in Python and  love NLP"]).toarray()
# Out:
# array([[0, 0, 2, 1, 1]])

# %% [markdown]
# N-grams

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv2 = CountVectorizer(ngram_range=(2,2))

X = cv2.fit_transform(corpus)

print(cv2.get_feature_names_out())
print(X.toarray())
# Out:
# ['is easy' 'love nlp' 'love python' 'python is']
# [[0 0 1 0]
#  [1 0 0 1]
#  [0 1 0 0]]

# %%
cv2.transform(["I love programming in Python,it is easy and I love NLP"]).toarray()
# Out:
# array([[1, 1, 0, 0]])

# %% [markdown]
# TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = [
    "I love Python",
    "Python is easy",
    "I love NLP"
]

tfidf = TfidfVectorizer()

X = tfidf.fit_transform(corpus)

print(tfidf.get_feature_names_out())


print(X.toarray())
# Out:
# ['easy' 'is' 'love' 'nlp' 'python']
# [[0.         0.         0.70710678 0.         0.70710678]
#  [0.62276601 0.62276601 0.         0.         0.4736296 ]
#  [0.         0.         0.60534851 0.79596054 0.        ]]

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)

import pandas as pd
import os

df = pd.read_csv(os.path.join(path, "IMDB Dataset.csv"))
# Out:
# Path to dataset files: C:\Users\LENOVO\.cache\kagglehub\datasets\lakshmi25npathi\imdb-dataset-of-50k-movie-reviews\versions\1

# %%
pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 3.3 MB/s eta 0:00:08
#    - -------------------------------------- 1.0/24.4 MB 2.9 MB/s eta 0:00:08
#    --- ------------------------------------ 1.8/24.4 MB 3.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.9/24.4 MB 3.5 MB/s eta 0:00:07
#    ------ --------------------------------- 3.7/24.4 MB 3.5 MB/s eta 0:00:06
#    ------- -------------------------------- 4.5/24.4 MB 3.4 MB/s eta 0:00:06
#    ------- -------------------------------- 4.5/24.4 MB 3.4 MB/s eta 0:00:06
#    -------- ------------------------------- 5.0/24.4 MB 2.9 MB/s eta 0:00:07
#    -------- ------------------------------- 5.2/24.4 MB 2.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 6.3/24.4 MB 2.9 MB/s eta 0:00:07
#    ------------ --------------------------- 7.3/24.4 MB 3.1 MB/s eta 0:00:06
# ...

# %%
from gensim.models import Word2Vec

sentences = [
    ["I", "love", "Python"],
    ["Python", "is", "easy"],
    ["I", "love", "NLP"]
]

model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4
)

print(model.wv["Python"])
# Out:
# [-5.3622725e-04  2.3643136e-04  5.1033497e-03  9.0092728e-03
#  -9.3029495e-03 -7.1168090e-03  6.4588725e-03  8.9729885e-03
#  -5.0154282e-03 -3.7633716e-03  7.3805046e-03 -1.5334714e-03
#  -4.5366134e-03  6.5540518e-03 -4.8601604e-03 -1.8160177e-03
#   2.8765798e-03  9.9187379e-04 -8.2852151e-03 -9.4488179e-03
#   7.3117660e-03  5.0702621e-03  6.7576934e-03  7.6286553e-04
#   6.3508903e-03 -3.4053659e-03 -9.4640139e-04  5.7685734e-03
#  -7.5216377e-03 -3.9361035e-03 -7.5115822e-03 -9.3004224e-04
#   9.5381187e-03 -7.3191668e-03 -2.3337686e-03 -1.9377411e-03
#   8.0774371e-03 -5.9308959e-03  4.5162440e-05 -4.7537340e-03
#  -9.6035507e-03  5.0072931e-03 -8.7595852e-03 -4.3918253e-03
#  -3.5099984e-05 -2.9618145e-04 -7.6612402e-03  9.6147433e-03
#   4.9820580e-03  9.2331432e-03 -8.1579173e-03  4.4957981e-03
#  -4.1370760e-03  8.2453608e-04  8.4986202e-03 -4.4621765e-03
#   4.5175003e-03 -6.7869602e-03 -3.5484887e-03  9.3985079e-03
# ...

# %%
print(model.wv.most_similar("Python"))
# Out:
# [('love', -0.010839177295565605), ('easy', -0.027750369161367416), ('I', -0.05234673619270325), ('is', -0.059876296669244766), ('NLP', -0.1116705909371376)]

# %%
pip install wget
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9683 sha256=8058217dab53bb613240fe1aecd44de49252b040e67882606743692ca9b5c9ba
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\8a\b8\04\0c88fb22489b0c049bee4e977c5689c7fe597d6c4b0e7d0b6a
# Successfully built wget
# ...
#   DEPRECATION: Building 'wget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wget'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# UsageError: Line magic function `%wget` not found.
