# %%
import logging

#configure basic logging setting
logging.basicConfig(level=logging.DEBUG)

#log messages fdifferent severity levels
logging.debug("This is debug message")
logging.info("This is info")
logging.warning("This is warning ")
logging.error("This is error")
logging.critical("Crirtical message")
# Out:
# DEBUG:root:This is debug message
# INFO:root:This is info
# WARNING:root:This is warning
# ERROR:root:This is error
# CRITICAL:root:Crirtical message

# %%
#configurinf logging
import logging

logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%H:%S'

)
logging.debug("This is debug message")
logging.info("This is info")
logging.warning("This is warning ")
logging.error("This is error")
logging.critical("Crirtical message")

# %%
import logging
#create logger for module
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)


#logger for module 2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(level=logging.DEBUG,
                     format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%H:%S'
                    )

# %%
logger1.debug("debug message")
logger2.warning("warning message")
# Out:
# 2025-12-11 14:14:27-module1-DEBUG-debug message
# 2025-12-11 14:14:27-module2-WARNING-warning message
