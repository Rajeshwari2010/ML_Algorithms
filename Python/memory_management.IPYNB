# %%
import gc 
gc.enable()

gc.collect()
# Out:
# 744

# %%
print(gc.garbage)
# Out:
# []

# %%
#garbage stats

print(gc.get_stats())
# Out:
# [{'collections': 70, 'collected': 1787, 'uncollectable': 0}, {'collections': 6, 'collected': 398, 'uncollectable': 0}, {'collections': 1, 'collected': 744, 'uncollectable': 0}]
